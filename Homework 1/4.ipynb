# %% [markdown]
# ## Условие 4:
# ## Даны два списка.
# ## Дата покупки
# ## ['2021-09-14', '2021-12-15', '2021-09-08', '2021-12-05', '2021-10-09', '2021-09-30', '2021-12-22', '2021-11-29', '2021-12-24', '2021-11-26', '2021-10-27', '2021-12-18', '2021-11-09', '2021-11-23', '2021-09-27', '2021-10-02', '2021-12-27', '2021-09-20', '2021-12-13', '2021-11-01', '2021-11-09', '2021-12-06', '2021-12-08', '2021-10-09', '2021-10-31', '2021-09-30', '2021-11-09', '2021-12-13', '2021-10-26', '2021-12-09']
# ## Суммы покупок по датам
# ## [1270, 8413, 9028, 3703, 5739, 4095, 295, 4944, 5723, 3701, 4471, 651, 7037, 4274, 6275, 4988, 6930, 2971, 6592, 2004, 2822, 519, 3406, 2732, 5015, 2008, 316, 6333, 5700, 2887]
# ### 4.1 Найдите, какая выручка у компании в ноябре
# ### Используйте list comprehensions

# %%
def november_sum (dates: list, summa: list) -> int:
    nov_purch = {dates[i]:summa[i] for i in range(len(summa)) if '2021-11' in dates[i]}
    print(nov_purch)
    summa_list = [value for value in nov_purch.values()]
    total = 0
    for i in summa_list:
        total += i
    return f'Сумма продаж за ноябрь - {total} рублей'

dates = ['2021-09-14', '2021-12-15', '2021-09-08', '2021-12-05', '2021-10-09', '2021-09-30', '2021-12-22', '2021-11-29', '2021-12-24', '2021-11-26', '2021-10-27', '2021-12-18', '2021-11-09', '2021-11-23', '2021-09-27', '2021-10-02', '2021-12-27', '2021-09-20', '2021-12-13', '2021-11-01', '2021-11-09', '2021-12-06', '2021-12-08', '2021-10-09', '2021-10-31', '2021-09-30', '2021-11-09', '2021-12-13', '2021-10-26', '2021-12-09']
summa = [1270, 8413, 9028, 3703, 5739, 4095, 295, 4944, 5723, 3701, 4471, 651, 7037, 4274, 6275, 4988, 6930, 2971, 6592, 2004, 2822, 519, 3406, 2732, 5015, 2008, 316, 6333, 5700, 2887]
november_sum(dates, summa)
# Out:
# {'2021-11-29': 4944, '2021-11-26': 3701, '2021-11-09': 316, '2021-11-23': 4274, '2021-11-01': 2004}
# 'Сумма продаж за ноябрь - 15239 рублей'

# %% [markdown]
# ### 4.2 Найдите выручку компании в зависимости от месяца
# ### Для этого напишите функцию, которая на вход принимает список с датами и список с выручкой, а на выходе словарь, где ключи - это месяцы, а значения - это выручка.
# ### Используйте аннотирование типов.

# %%
import numpy as np
def total (l1: list) -> int:
    total = 0
    for i in l1:
        total += i
    return total

def all_months (dates: list, summa: list) -> dict:
    keys = ['Сентябрь', 'Октябрь', 'Ноябрь', 'Декабрь']
    september = []
    october = []
    november=[]
    december = []
    for i in range(len(dates)):
        if '2021-09' in dates[i]:
            september.append(summa[i])
        if '2021-10' in dates[i]:
            october.append(summa[i])
        if '2021-11' in dates[i]:
            november.append(summa[i]) 
        if '2021-12' in dates[i]:
            december.append(summa[i])
    print(september)
    print(october)
    print(november)
    print(december)        
    final = {keys[0]:total(september), keys[1]: total(october), keys[2]: total(november), keys[3]: total(december)}
    print(final)

dates = ['2021-09-14', '2021-12-15', '2021-09-08', '2021-12-05', '2021-10-09', '2021-09-30', '2021-12-22', '2021-11-29', '2021-12-24', '2021-11-26', '2021-10-27', '2021-12-18', '2021-11-09', '2021-11-23', '2021-09-27', '2021-10-02', '2021-12-27', '2021-09-20', '2021-12-13', '2021-11-01', '2021-11-09', '2021-12-06', '2021-12-08', '2021-10-09', '2021-10-31', '2021-09-30', '2021-11-09', '2021-12-13', '2021-10-26', '2021-12-09']
summa = [1270, 8413, 9028, 3703, 5739, 4095, 295, 4944, 5723, 3701, 4471, 651, 7037, 4274, 6275, 4988, 6930, 2971, 6592, 2004, 2822, 519, 3406, 2732, 5015, 2008, 316, 6333, 5700, 2887]
all_months(dates, summa) 
print(np.sum(summa))
# Out:
# [1270, 9028, 4095, 6275, 2971, 2008]
# [5739, 4471, 4988, 2732, 5015, 5700]
# [4944, 3701, 7037, 4274, 2004, 2822, 316]
# [8413, 3703, 295, 5723, 651, 6930, 6592, 519, 3406, 6333, 2887]
# {'Сентябрь': 25647, 'Октябрь': 28645, 'Ноябрь': 25098, 'Декабрь': 45452}
# 124842
